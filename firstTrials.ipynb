# %%
import pandas as pd

# Set option to show full text
pd.set_option('display.max_colwidth', None)

# Load your data
df = pd.read_csv(
    './amazon_review_full_csv/train.csv',
    header=None,
    names=['label', 'title', 'text'],
    quotechar='"',
    doublequote=True,
    escapechar='\\',
    engine='python',
    encoding='utf-8',
    nrows=1000
)

# Optional: decode escape characters
#df['text'] = df['text'].str.encode('utf-8').str.decode('unicode_escape')

# Display full text for first 10 rows
df[['label', 'title', 'text']].head(50)
# Out:
#     label                                                         title  \
# 0       3                                            more like funchuck
# 1       5                                                     Inspiring
# 2       5                         The best soundtrack ever to anything.
# 3       4                                              Chrono Cross OST
# 4       5                                           Too good to be true
# 5       5                                There's a reason for the price
# 6       1                                                  Buyer beware
# 7       4                                       Errors, but great story
# 8       1                                                    The Worst!
# 9       1                                                     Oh please
# 10      1                                          Awful beyond belief!
# 11      4                                A romantic zen baseball comedy
# ...
