# %% [markdown]
# ### **Text Processing**
#
# I think it would be great to do some **text processing** in order to clean our dataset. Our model will perform better (i hope).
# What I'm going to do is:
#
# 1. Lowercasing - **our textbook says for sentiment analysis to not do this**
# 2. Removing Punctuation
# 3. Removing stopwords
# 4. Lemmatization (important task i think) - **I used SpaCy, NLTK need POS**
# 5. Removing special characters

# %% [markdown]
# #### **1 - Libraryes**
# - For today I'll use NLTK for lemmatization

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Download NLTK resources (run only once)
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\molna\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\molna\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
#  #### **2 - Quick look at our dataset**
#
#  - The dataset isn't so bad, in the past i worked on datasets very dirty: some rows full of emoticons
#  - We have 3 columns:
#    - *Rating:* from 1 to 5
#    - *Title of the review:* a string of text
#    - *Review:* a string of text

# %%
df = pd.read_csv("amazon_review_full_csv/train.csv", delimiter=';', encoding='latin1')  
# HOW MANY ROWS AND COLUMNS?
print("Dataset shape:", df.shape)
# LET'S SEE SOME ROWS
df.head(25)
# Out:
# Dataset shape: (1048575, 3)
#     Rating                                              Title  \
# 0        3                                 more like funchuck
# 1        5                                          Inspiring
# 2        5              The best soundtrack ever to anything.
# 3        4                                   Chrono Cross OST
# 4        5                                Too good to be true
# 5        5                     There's a reason for the price
# 6        1                                       Buyer beware
# 7        4                            Errors, but great story
# 8        1                                         The Worst!
# 9        1                                          Oh please
# 10       1                               Awful beyond belief!
# 11       4                     A romantic zen baseball comedy
# 12       5                   Lower leg comfort for 12 hours +
# 13       3                   Delivery was very long wait.....
# 14       2    sizes recomended in the size chart are not real
# 15       3                                           Overbury
# 16       1                       Another Abysmal Digital Copy
# 17       4                  Wardell's book is a pure delight.
# 18       4     i liked this album more then i thought i would
# 19       3                             Better than I thought.
# 20       3  The great Roy Orbison deserves a better qualit...
# 21       2                 Problem with charging smaller AAAs
# 22       5                       CHECK OUT THE K6000 CHARGER!
# 23       5                                               ahhh
# 24       5                                  Excellent Product
#
#                                                Review
# 0   Gave this to my dad for a gag gift after direc...
# 1   I hope a lot of people hear this cd. We need m...
# 2   I'm reading a lot of reviews saying that this ...
# 3   The music of Yasunori Misuda is without questi...
# 4   Probably the greatest soundtrack in history! U...
# 5   There's a reason this CD is so expensive, even...
# 6   This is a self-published book, and if you want...
# 7   I was a dissapointed to see errors on the back...
# 8   A complete waste of time. Typographical errors...
# 9   I guess you have to be a romance novel lover f...
# 10  I feel I have to write to keep others from was...
# 11  When you hear folks say that they don't make '...
# 12  Excellent stockings for long shifts on your fe...
# 13  It took almost 3 weeks to recieve the two pair...
# 14  sizes are much smaller than what is recomended...
# 15  Full of intrigue and a good overview of the co...
# 16  Rather than scratches and insect droppings, th...
# 17  Steven Wardell's book is a pure delight and I'...
# 18  I heard a song or two and thought same o same ...
# 19  I wrote a harsh review based on hearing a coup...
# 20  When I saw the term 'bootleg' on the title of ...
# 21  I have had the charger for more than two years...
# 22  Greetings. Kodak also has a K6000 charger whic...
# 23  These will more than pay for themselves, they ...
# 24  This is an excellent product. I bought this fo...

# %% [markdown]
# #### **3 - Cleaning Text**
# - I've created a list of words that i think are usefull for our analysis so they are not considered stopwords even if they are
# - Put all in lowercase
# - Removed punctuation, only mantained ! and ?, max 1 occurrency
# - Removed stopwords

# %%
# LOAD THE STOPWORDS (FROM NLTK)
stop_words = set(stopwords.words('english'))

# Words that are considered stopwords but i don't want to remove
important_words = {
    "not", "no", "nor", "never", "none", "nobody", "nothing", "neither", "nowhere",
    "don’t", "doesn’t", "didn’t", "can’t", "couldn’t", "won’t", "wouldn’t",
    "shouldn’t", "wasn’t", "weren’t", "isn’t", "aren’t", "hasn’t", "haven’t", "hadn’t",
    "cannot", "without", "hardly", "barely", "rarely", "scarcely"
}
stop_words = stop_words - important_words 

def cleaning1(text):
    # Convert all the text to lowercase (optional)
    text = str(text).lower()

    # Replace multiple ! and ? with only one occurrency! 
    text = re.sub(r'[!]{2,}', '!', text)  # OK !!! --> ok !
    text = re.sub(r'[?]{2,}', '?', text)  # Are you ok??? --> are you ok?

    # Remove any special characters except for a single ! or ?
    # It avoids emoticons, urls ecc... (WATCH AGAIN LATER)
    text = re.sub(r'[^a-z0-9\s!?]', '', text)  
    
    # Tokenize and remove stopwords
    words = text.split()
    words = [word for word in words if word not in stop_words]
    
    return ' '.join(words)

df['Title'] = df['Title'].apply(cleaning1)
df['Review'] = df['Review'].apply(cleaning1)

df.head(25)
# Out:
#     Rating                                              Title  \
# 0        3                                      like funchuck
# 1        5                                          inspiring
# 2        5                      best soundtrack ever anything
# 3        4                                   chrono cross ost
# 4        5                                          good true
# 5        5                                theres reason price
# 6        1                                       buyer beware
# 7        4                                 errors great story
# 8        1                                              worst
# 9        1                                          oh please
# 10       1                                awful beyond belief
# 11       4                       romantic zen baseball comedy
# 12       5                         lower leg comfort 12 hours
# 13       3                                 delivery long wait
# 14       2               sizes recomended size chart not real
# 15       3                                           overbury
# 16       1                       another abysmal digital copy
# 17       4                         wardells book pure delight
# 18       4                          liked album thought would
# 19       3                                     better thought
# 20       3  great roy orbison deserves better quality reco...
# 21       2                      problem charging smaller aaas
# 22       5                                check k6000 charger
# 23       5                                               ahhh
# 24       5                                  excellent product
#
#                                                Review
# 0   gave dad gag gift directing nunsense got reall...
# 1   hope lot people hear cd need strong positive v...
# 2   im reading lot reviews saying best game soundt...
# 3   music yasunori misuda without question close s...
# 4   probably greatest soundtrack history usually b...
# 5   theres reason cd expensive even version thats ...
# 6   selfpublished book want know whyread paragraph...
# 7   dissapointed see errors back cover since paid ...
# 8   complete waste time typographical errors poor ...
# 9   guess romance novel lover one not discerning o...
# 10  feel write keep others wasting money book seem...
# 11  hear folks say dont make em like anymore might...
# 12  excellent stockings long shifts feet not tight...
# 13  took almost 3 weeks recieve two pairs stocking...
# 14  sizes much smaller recomended chart tried put ...
# 15  full intrigue good overview court james 1 key ...
# 16  rather scratches insect droppings one random p...
# 17  steven wardells book pure delight ive recommen...
# 18  heard song two thought obut listened songs lik...
# 19  wrote harsh review based hearing couple tracks...
# 20  saw term bootleg title recordingi see mean one...
# 21  charger two years charges aa batteries fine hu...
# 22  greetings kodak also k6000 charger comes 4 nim...
# 23  pay perfect gps drain cheap battery less hourb...
# 24  excellent product bought digital camera great ...

# %% [markdown]
# #### **3 - Lemmatization with SpaCy**
#
# For run this you need to install SpaCy. You can find more informations about it on the web or in the notebook of professor's Ceni.
# I prefered to use this instead of using nltk because nltk needs also pos-tagging.
#
# - I run the lemmatizer only on first 1000 rows just for understand how much time it takes (Very few)
# - Created a second dataframe to watch the results
# - I use **Ryzen 7 5700G, 8 core 3.8 Ghz, and a RX 6600 6GB, 32GB RAM DDR4**

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

#LEMMATIZATION FUNCTION

def lemmatize_text(text):
    #spaCy
    doc = nlp(str(text))  
    return " ".join([token.lemma_ for token in doc])

#ONLY ON FIRST 1000 ROWS
df_subset = df.iloc[:1000].copy()  

df_subset['Title'] = df_subset['Title'].apply(lemmatize_text)
df_subset['Review'] = df_subset['Review'].apply(lemmatize_text)

print(df_subset[['Title', 'Review']].head(25))
# Out:
#                                                Title  \
# 0                                      like funchuck
# 1                                            inspire
# 2                      good soundtrack ever anything
# 3                                   chrono cross ost
# 4                                          good true
# 5                               there s reason price
# 6                                       buyer beware
# 7                                  error great story
# 8                                              worst
# 9                                          oh please
# 10                               awful beyond belief
# 11                      romantic zen baseball comedy
# 12                           low leg comfort 12 hour
# 13                                delivery long wait
# 14                size recomende size chart not real
# 15                                          overbury
# 16                      another abysmal digital copy
# 17                         wardell book pure delight
# 18                            like album think would
# 19                                      well thought
# 20  great roy orbison deserve well quality recording
# 21                         problem charge small aaas
# 22                               check k6000 charger
# 23                                              ahhh
# 24                                 excellent product
#
#                                                Review
# 0   give dad gag gift directing nunsense get reall...
# 1   hope lot people hear cd need strong positive v...
# 2   I m read lot review say good game soundtrack f...
# 3   music yasunori misuda without question close s...
# 4   probably great soundtrack history usually well...
# 5   there s reason cd expensive even version that ...
# 6   selfpublishe book want know whyread paragraph ...
# 7   dissapointed see error back cover since pay bo...
# 8   complete waste time typographical error poor g...
# 9   guess romance novel lover one not discern one ...
# 10  feel write keep other waste money book seems w...
# 11  hear folk say do not make em like anymore migh...
# 12  excellent stocking long shift foot not tight n...
# 13  take almost 3 week recieve two pair stocking o...
# 14  size much small recomende chart try put sheer ...
# 15  full intrigue good overview court jame 1 key p...
# 16  rather scratch insect dropping one random pixe...
# 17  steven wardell book pure delight I ve recommen...
# 18  hear song two thought obut listen song like bl...
# 19  write harsh review base hear couple track one ...
# 20  see term bootleg title recordingi see mean one...
# 21  charger two year charge aa battery fine huge p...
# 22  greeting kodak also k6000 charger come 4 nimh ...
# 23  pay perfect gps drain cheap battery less hourb...
# 24  excellent product buy digital camera great bat...
